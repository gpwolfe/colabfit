# %%
import numpy as np
from colabfit_utilities import assemble_np

# %%
data = np.load('/Users/piper/Downloads/data(3).npy')
data2 = np.load('/Users/piper/Downloads/data(2).npy')
data3 = np.load('/Users/piper/Downloads/data(4).npy')

# %%
assemble_np({
    '/Users/piper/Downloads/data(4).npy': 'number',
    '/Users/piper/Downloads/data(2).npy': 'coords',
    
            }, {'numbers':None, 'coords':None})
# Out:
# {'number': array([6, 1, 1, 1, 6, 7, 6, 1, 1, 1, 6, 7, 6, 1, 1, 1, 6, 7, 6, 1, 1, 1,
#         6, 7, 6, 1, 1, 1, 6, 7, 6, 1, 1, 1, 6, 7, 6, 1, 1, 1, 6, 7, 6, 1,
#         1, 1, 6, 7, 6, 1, 1, 1, 6, 7, 6, 1, 1, 1, 6, 7, 6, 1, 1, 1, 6, 7,
#         6, 1, 1, 1, 6, 7, 6, 1, 1, 1, 6, 7, 6, 1, 1, 1, 6, 7, 6, 1, 1, 1,
#         6, 7, 6, 1, 1, 1, 6, 7]),
#  'coords': array([[[-4.27174976, -3.66712164, -1.57381852],
#          [-3.98442976, -2.69669164, -1.98620852],
#          [-5.22943976, -3.97402164, -2.00085852],
#          [-3.50869976, -4.41040164, -1.82345852],
#          [-4.37309976, -3.56294164, -0.13654852],
#          [-4.44174976, -3.48179164,  1.02549248],
#          [ 0.57198824, -4.87304164, -1.51246852],
#          [ 1.54612024, -4.65669164, -1.96116852],
#          [-0.17208976, -4.15667164, -1.87434852],
#          [ 0.24595224, -5.87782164, -1.79023852],
#          [ 0.67460624, -4.76258164, -0.07553852],
#          [ 0.76796924, -4.66137164,  1.08329948],
# ...

# %%
data2
# Out:
# array([[[-4.27174976, -3.66712164, -1.57381852],
#         [-3.98442976, -2.69669164, -1.98620852],
#         [-5.22943976, -3.97402164, -2.00085852],
#         [-3.50869976, -4.41040164, -1.82345852],
#         [-4.37309976, -3.56294164, -0.13654852],
#         [-4.44174976, -3.48179164,  1.02549248],
#         [ 0.57198824, -4.87304164, -1.51246852],
#         [ 1.54612024, -4.65669164, -1.96116852],
#         [-0.17208976, -4.15667164, -1.87434852],
#         [ 0.24595224, -5.87782164, -1.79023852],
#         [ 0.67460624, -4.76258164, -0.07553852],
#         [ 0.76796924, -4.66137164,  1.08329948],
#         [-2.23540976, -5.79166164,  2.02490248],
#         [-3.01298976, -5.07328164,  2.30167748],
#         [-1.25568976, -5.40979164,  2.32883348],
#         [-2.42328976, -6.73750164,  2.53819448],
#         [-2.24730976, -5.98037164,  0.59142348],
#         [-2.24948976, -6.12094164, -0.56635852],
#         [ 3.76848224, -3.55370164,  1.57317548],
# ...

# %%
list(zip(data, data2[0], data3))
# Out:
# [(0, array([-4.27174976, -3.66712164, -1.57381852]), 6),
#  (0, array([-3.98442976, -2.69669164, -1.98620852]), 1),
#  (0, array([-5.22943976, -3.97402164, -2.00085852]), 1),
#  (0, array([-3.50869976, -4.41040164, -1.82345852]), 1),
#  (0, array([-4.37309976, -3.56294164, -0.13654852]), 6),
#  (0, array([-4.44174976, -3.48179164,  1.02549248]), 7),
#  (1, array([ 0.57198824, -4.87304164, -1.51246852]), 6),
#  (1, array([ 1.54612024, -4.65669164, -1.96116852]), 1),
#  (1, array([-0.17208976, -4.15667164, -1.87434852]), 1),
#  (1, array([ 0.24595224, -5.87782164, -1.79023852]), 1),
#  (1, array([ 0.67460624, -4.76258164, -0.07553852]), 6),
#  (1, array([ 0.76796924, -4.66137164,  1.08329948]), 7),
#  (2, array([-2.23540976, -5.79166164,  2.02490248]), 6),
#  (2, array([-3.01298976, -5.07328164,  2.30167748]), 1),
#  (2, array([-1.25568976, -5.40979164,  2.32883348]), 1),
#  (2, array([-2.42328976, -6.73750164,  2.53819448]), 1),
# ...
